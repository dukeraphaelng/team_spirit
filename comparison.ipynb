# %%
import pandas as pd
import numpy as np

svm_df = pd.read_csv('svm_stats.csv')
svm_df['log_loss'] = [np.nan for i in range(len(svm_df))]
transformer_df = pd.read_csv('transformer_stats.csv')
stats = pd.concat([transformer_df, svm_df], axis=0)
stats = stats.rename(columns={stats.columns[0]: 'model'})
stats = stats.reset_index(drop=True)
stats.at[0, 'model'] = 'Max-Pooling BERT'
stats.at[1, 'model'] = 'Mean-Pooling BERT'
stats = stats.set_index('model')
stats.to_csv('stats.csv')
stats
# Out:
#                    cohen_kappa  matthews_corrcoef  log_loss  micro-accuracy  \
# model
# Max-Pooling BERT      0.903966           0.904197  2.698977        0.907167
# Mean-Pooling BERT     0.896552           0.896801  2.319134        0.900000
# Raw SVM               0.819071           0.821772       NaN        0.825112
# 1-layer SDAE SVM      0.962888           0.962963       NaN        0.964126
# 2-layers SDAE SVM     0.939691           0.939941       NaN        0.941704
# 3-layers SDAE SVM     0.935053           0.935272       NaN        0.937220
#
#                    macro avg precision  macro avg recall  macro avg f1-score  \
# model
# Max-Pooling BERT              0.913532          0.907167            0.906943
# Mean-Pooling BERT             0.906794          0.900000            0.899752
# Raw SVM                       0.881030          0.824921            0.837734
# 1-layer SDAE SVM              0.966423          0.964127            0.964198
# 2-layers SDAE SVM             0.948037          0.941429            0.941132
# 3-layers SDAE SVM             0.943550          0.936825            0.936844
#
#                    weighted avg precision  weighted avg recall  \
# model
# Max-Pooling BERT                 0.913532             0.907167
# Mean-Pooling BERT                0.906794             0.900000
# Raw SVM                          0.880422             0.825112
# 1-layer SDAE SVM                 0.966271             0.964126
# 2-layers SDAE SVM                0.947720             0.941704
# 3-layers SDAE SVM                0.943503             0.937220
#
#                    weighted avg f1-score
# model
# Max-Pooling BERT                0.906943
# Mean-Pooling BERT               0.899752
# Raw SVM                         0.837551
# 1-layer SDAE SVM                0.964120
# 2-layers SDAE SVM               0.941138
# 3-layers SDAE SVM               0.937043
